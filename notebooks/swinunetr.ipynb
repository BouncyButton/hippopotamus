# %%
try:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    wandb_api_key = user_secrets.get_secret("WANDB_API_KEY")
except:
    from google.colab import userdata
    wandb_api_key = userdata.get('WANDB_API_KEY')

# %%
# Write the .netrc file
netrc_content = f"""machine api.wandb.ai
  login user
  password {wandb_api_key}
"""

with open("/root/.netrc", "w") as f:
    f.write(netrc_content)

# Make sure permissions are correct
import os
os.chmod("/root/.netrc", 0o600)

# %%
# %cd /content
# !git clone https://github.com/BouncyButton/hippopotamus
# !pip install wget
# !mkdir datasets
# %cd datasets

# %%
# !python /content/hippopotamus/datasets/Dataset102_MNI/create_mni_dataset.py

# %%
# %cd /content/hippopotamus/baselines

# %%
# !pip install monai

# %%
# %cd /content/hippopotamus/
# !git pull

# %%
# !python /content/hippopotamus/baselines/swin_unetr/swin_unetr.py \
  --pkl /content/datasets/Dataset102_MNI/mni_hippocampus_full.pkl \
  --dataset MNI \
  --fold 0 \
  --splits-json datasets/Dataset102_MNI/splits_final.json \
  --epochs 250 \

# %%
# !python /content/hippopotamus/baselines/swin_unetr/swin_unetr.py \
  --pkl /content/datasets/Dataset102_MNI/mni_hippocampus_full.pkl \
  --dataset MNI \
  --fold 1 \
  --splits-json datasets/Dataset102_MNI/splits_final.json \
  --epochs 250 \

# %%
# !python /content/hippopotamus/baselines/swin_unetr/swin_unetr.py \
  --pkl /content/datasets/Dataset102_MNI/mni_hippocampus_full.pkl \
  --dataset MNI \
  --fold 2 \
  --splits-json datasets/Dataset102_MNI/splits_final.json \
  --epochs 250 \

# %%
# !python /content/hippopotamus/baselines/swin_unetr/swin_unetr.py \
  --pkl /content/datasets/Dataset102_MNI/mni_hippocampus_full.pkl \
  --dataset MNI \
  --fold 3 \
  --splits-json datasets/Dataset102_MNI/splits_final.json \
  --epochs 250 \

# %%
# !python /content/hippopotamus/baselines/swin_unetr/swin_unetr.py \
  --pkl /content/datasets/Dataset102_MNI/mni_hippocampus_full.pkl \
  --dataset MNI \
  --fold 4 \
  --splits-json datasets/Dataset102_MNI/splits_final.json \
  --epochs 250 \
